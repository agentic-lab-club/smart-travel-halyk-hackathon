# %% [markdown]
# # DeepSeek AI Agent + Analytics DB
#
# Этот notebook загружает API-ключ DeepSeek из `.env`, подключается к PostgreSQL (analytics_db) и выполняет тестовый запрос.

# %%
# Устанавливаем зависимости (используйте psycopg2-binary, чтобы не собирать из исходников)
# !pip install python-dotenv requests psycopg2-binary -q

# %%
import os
from dotenv import load_dotenv
import requests
import json
import psycopg2

# Загружаем переменные окружения из .env (ищет в текущей директории и родительских)
load_dotenv()

# Получаем API-ключ DeepSeek
DEEPSEEK_API_KEY = os.getenv('DEEPSEEK_API_KEY')

if not DEEPSEEK_API_KEY or DEEPSEEK_API_KEY == 'your_api_key_here':
    raise ValueError("API ключ DeepSeek не найден в .env или не задан")

# Подключение к PostgreSQL
DATABASE_URL = os.getenv('DATABASE_URL', 'postgresql://analytics:analytics_pass@localhost:5432/analytics_db')
conn = psycopg2.connect(DATABASE_URL)
cur = conn.cursor()
cur.execute("SELECT version();")
db_version = cur.fetchone()[0]
cur.close()
conn.close()

print("API-ключ загружен успешно")
print("DB подключена:", db_version)
# Out:
# API-ключ загружен успешно
# DB подключена: PostgreSQL 16.14 on x86_64-pc-linux-musl, compiled by gcc (Alpine 15.2.0) 15.2.0, 64-bit

# %%
cur.execute("""SELECT

# %%
# Параметры запроса к DeepSeek API
BASE_URL = "https://api.deepseek.com/v1"

headers = {
    "Authorization": f"Bearer {DEEPSEEK_API_KEY}",
    "Content-Type": "application/json"
}

payload = {
    "model": "deepseek-chat",
    "messages": [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Привет! Как дела?"}
    ],
    "temperature": 0.7,
    "max_tokens": 500
}

response = requests.post(f"{BASE_URL}/chat/completions", headers=headers, json=payload)
response.raise_for_status()

result = response.json()
print(json.dumps(result, indent=2, ensure_ascii=False))

# %%
# Выводим только ответ модели
reply = result["choices"][0]["message"]["content"]
print("Ответ модели:")
print(reply)
